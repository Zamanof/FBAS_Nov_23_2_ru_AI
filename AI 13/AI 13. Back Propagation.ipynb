# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - Схема обучения
#     - Forward propagation - вычислить предсказание
#     - Loss function - вычислить ошибку
#     - Backward propagation - найти градиенты (веса которые ошиблись)
#     - Gradient descent - обновить веса
#     - Повторить много раз

# %%
def sigmoid(z):
    return 1 / (1+np.exp(-z))

def sigmoid_grad(a):
    return a * (1 - a)

def relu(z):
    return np.maximum(0, z)

def relu_grad(a):
    return (a > 0).astype(float)

# %% [markdown]
# $$
# ReLU(x) = max(0, x)
# $$
#
# $$
# \sigma(x) = \frac{1}{1+e^{-x}}
# $$

# %%
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])

# %% [markdown]
# $$
# W = random * \sqrt{\frac{2}{inputsize}}
# $$

# %%
np.random.seed(0)

hidden_size = 4
# He initialization
W1 = np.random.randn(2, hidden_size) * np.sqrt(2.0 / 2)
b1 = np.zeros((1, hidden_size))
W2 = np.random.randn(hidden_size, 1) * np.sqrt(2.0 / hidden_size)
b2 = np.zeros((1, 1))

lr = 0.1

# %% [markdown]
# ### Forward propagation
#
# $$
# Z_1 = XW_1 + b_1A_1 = ReLU(Z_1)
# $$
#
#
# $$
# Z_2 = XW_2 + b_2A_2 = sigmoid(Z_2)
# $$

# %%
def forward(X, W1, b1, W2, b2):
    Z1 = X @ W1 + b1
    A1 = relu(Z1)
    Z2 = A1 @ W2 + b2
    A2 = sigmoid(Z2)
    return Z1, A1, Z2, A2

# %%
def backward(X, y, Z1, A1,  A2, W2):
    m = len(X)

    dZ2 = A2 - y
    dW2 = A1.T @ dZ2 / m
    db2 = np.sum(dZ2, axis=0, keepdims=True) / m

    dA1 = dZ2 @ W2.T
    dZ1 = dA1 * relu_grad(Z1)
    dW1 = X.T @ dZ1 / m
    db1 = np.sum(dZ1, axis=0, keepdims=True) / m

    return dW1, db1, dW2, db2

# %%
losses = []

for epoch in range(6000):
    Z1, A1, Z2, A2 = forward(X, W1, b1, W2, b2)

    loss = -np.mean(y * np.log(A2+1e-8) + (1-y)*np.log(1-A2 + 1e-8))
    losses.append(loss)

    dW1, db1, dW2, db2 = backward(X, y, Z1, A1, A2, W2)

    W1 -= lr * dW1
    b1 -= lr * db1
    W2 -= lr * dW2
    b2 -= lr * db2

    if ((epoch+1) % 100) == 0:
        predictions = (A2 > 0.5).astype(int).ravel()
        print(f"Epoch: {epoch+1} Loss: {loss:.4f} Predictions: {predictions}")

print("Ready")
# Out:
# Epoch: 100 Loss: 0.5876 Predictions: [0 0 1 0]
# Epoch: 200 Loss: 0.5052 Predictions: [0 0 1 0]
# Epoch: 300 Loss: 0.4771 Predictions: [0 0 1 0]
# Epoch: 400 Loss: 0.3963 Predictions: [0 0 1 0]
# Epoch: 500 Loss: 0.2397 Predictions: [0 1 1 0]
# Epoch: 600 Loss: 0.1333 Predictions: [0 1 1 0]
# Epoch: 700 Loss: 0.0764 Predictions: [0 1 1 0]
# Epoch: 800 Loss: 0.0492 Predictions: [0 1 1 0]
# Epoch: 900 Loss: 0.0347 Predictions: [0 1 1 0]
# Epoch: 1000 Loss: 0.0261 Predictions: [0 1 1 0]
# Epoch: 1100 Loss: 0.0206 Predictions: [0 1 1 0]
# Epoch: 1200 Loss: 0.0168 Predictions: [0 1 1 0]
# Epoch: 1300 Loss: 0.0140 Predictions: [0 1 1 0]
# Epoch: 1400 Loss: 0.0120 Predictions: [0 1 1 0]
# Epoch: 1500 Loss: 0.0104 Predictions: [0 1 1 0]
# Epoch: 1600 Loss: 0.0092 Predictions: [0 1 1 0]
# Epoch: 1700 Loss: 0.0082 Predictions: [0 1 1 0]
# Epoch: 1800 Loss: 0.0074 Predictions: [0 1 1 0]
# Epoch: 1900 Loss: 0.0067 Predictions: [0 1 1 0]
# Epoch: 2000 Loss: 0.0061 Predictions: [0 1 1 0]
# Epoch: 2100 Loss: 0.0056 Predictions: [0 1 1 0]
# Epoch: 2200 Loss: 0.0052 Predictions: [0 1 1 0]
# Epoch: 2300 Loss: 0.0048 Predictions: [0 1 1 0]
# Epoch: 2400 Loss: 0.0045 Predictions: [0 1 1 0]
# Epoch: 2500 Loss: 0.0042 Predictions: [0 1 1 0]
# Epoch: 2600 Loss: 0.0039 Predictions: [0 1 1 0]
# Epoch: 2700 Loss: 0.0037 Predictions: [0 1 1 0]
# Epoch: 2800 Loss: 0.0035 Predictions: [0 1 1 0]
# Epoch: 2900 Loss: 0.0033 Predictions: [0 1 1 0]
# Epoch: 3000 Loss: 0.0031 Predictions: [0 1 1 0]
# Epoch: 3100 Loss: 0.0030 Predictions: [0 1 1 0]
# Epoch: 3200 Loss: 0.0028 Predictions: [0 1 1 0]
# Epoch: 3300 Loss: 0.0027 Predictions: [0 1 1 0]
# Epoch: 3400 Loss: 0.0026 Predictions: [0 1 1 0]
# Epoch: 3500 Loss: 0.0025 Predictions: [0 1 1 0]
# Epoch: 3600 Loss: 0.0024 Predictions: [0 1 1 0]
# Epoch: 3700 Loss: 0.0023 Predictions: [0 1 1 0]
# Epoch: 3800 Loss: 0.0022 Predictions: [0 1 1 0]
# Epoch: 3900 Loss: 0.0021 Predictions: [0 1 1 0]
# Epoch: 4000 Loss: 0.0020 Predictions: [0 1 1 0]
# Epoch: 4100 Loss: 0.0020 Predictions: [0 1 1 0]
# Epoch: 4200 Loss: 0.0019 Predictions: [0 1 1 0]
# Epoch: 4300 Loss: 0.0018 Predictions: [0 1 1 0]
# Epoch: 4400 Loss: 0.0018 Predictions: [0 1 1 0]
# Epoch: 4500 Loss: 0.0017 Predictions: [0 1 1 0]
# Epoch: 4600 Loss: 0.0017 Predictions: [0 1 1 0]
# Epoch: 4700 Loss: 0.0016 Predictions: [0 1 1 0]
# Epoch: 4800 Loss: 0.0016 Predictions: [0 1 1 0]
# Epoch: 4900 Loss: 0.0015 Predictions: [0 1 1 0]
# Epoch: 5000 Loss: 0.0015 Predictions: [0 1 1 0]
# Epoch: 5100 Loss: 0.0014 Predictions: [0 1 1 0]
# Epoch: 5200 Loss: 0.0014 Predictions: [0 1 1 0]
# Epoch: 5300 Loss: 0.0014 Predictions: [0 1 1 0]
# Epoch: 5400 Loss: 0.0013 Predictions: [0 1 1 0]
# Epoch: 5500 Loss: 0.0013 Predictions: [0 1 1 0]
# Epoch: 5600 Loss: 0.0013 Predictions: [0 1 1 0]
# Epoch: 5700 Loss: 0.0012 Predictions: [0 1 1 0]
# Epoch: 5800 Loss: 0.0012 Predictions: [0 1 1 0]
# Epoch: 5900 Loss: 0.0012 Predictions: [0 1 1 0]
# Epoch: 6000 Loss: 0.0012 Predictions: [0 1 1 0]
# Ready

# %%
plt.plot(losses)
plt.title("Loss Function")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.show()
